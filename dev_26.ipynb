# %%
import nest_asyncio 
nest_asyncio.apply()

import sys

sys.path.append('src')
from pathlib import Path
from streetparade_embeddings.soundcloud import ArtistData, discover_track_urls_sync

artist_name = "Hilit Kolet"
artist_url = "https://soundcloud.com/hilitkolet"

cache_dir = Path(".songs_cache")
max_tracks = 5

# Discover track URLs from the artist's SoundCloud /tracks page.
track_urls = discover_track_urls_sync(artist_url)

print(f"Found {len(track_urls)} tracks")
for url in track_urls[:max_tracks]:
    print(url)

# Download and cache the first N tracks.
artist_data = ArtistData(
    artist=artist_name,
    links=track_urls,
    cache_folder=cache_dir,
)

downloads = artist_data.download_links(num_links=max_tracks)
# Out:
# [INFO] Starting Chromium download.
# 100%|██████████| 183M/183M [00:06<00:00, 27.9Mb/s]
# [INFO] Beginning extraction
# [INFO] Chromium extracted to: /home/charilaos/.local/share/pyppeteer/local-chromium/1181205
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error Target.detachFromTarget: Target closed.')>
# pyppeteer.errors.NetworkError: Protocol error Target.detachFromTarget: Target closed.
# Future exception was never retrieved
# future: <Future finished exception=NetworkError('Protocol error (Target.sendMessageToTarget): No session with given id')>
# pyppeteer.errors.NetworkError: Protocol error (Target.sendMessageToTarget): No session with given id
# Found 8 tracks
# https://soundcloud.com/hilitkolet/solid-groove-this-is-sick-hilit-kolet-edit
# https://soundcloud.com/hilitkolet/hilit-kolet-i-want-your-soul
# https://soundcloud.com/hilitkolet/hilit-kolet-radio-1-peak-time-mix-sarah-story-future-dance
# https://soundcloud.com/hilitkolet/hilit-kolet-everything-is-3
# https://soundcloud.com/hilitkolet/hilit-kolet-everything-is-2
# <class 'urllib.error.HTTPError'> HTTP Error 401: Unauthorized
# <class 'urllib.error.HTTPError'> HTTP Error 401: Unauthorized
# <class 'urllib.error.HTTPError'> HTTP Error 401: Unauthorized
# <class 'urllib.error.HTTPError'> HTTP Error 401: Unauthorized

# %%
# Out:
# PosixPath('.songs_cache/6547d9473d752454090bd02181e43724')

# %%
# !ls
# Out:
# artist_links.json    docs	      README.md		      tests
# compute_emb.ipynb    embed.ipynb      requirements_emb.txt    utils.py
# create_embedings.py  make_page.ipynb  src
# dev.ipynb	     pyproject.toml   streetparade_data.html
